# %%
from networkx_traffic_sim_playkit import *
from visualization_traffic_sim import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from networkx_traffic_sim_playkit import *
#       2 from visualization_traffic_sim import *
#
# File ~\OneDrive\Documents\GitHub\LA-Transport-PIC16B\research\NetworkX Compatibility\networkx_traffic_sim_playkit.py:3
#       1 # Contains many different sample road networks for analyzing certain patterns, case studies of real life road networks, etc.
# ----> 3 from networkx_traffic_sim import *
#       5 def template_2input_1sink():
#       6     m = Map(confirmation_messages = False)
#
# ModuleNotFoundError: No module named 'networkx_traffic_sim'

# %%
m = template_2input_1sink()
simulate(m)
# Out:
#  99%|█████████▉| 99/100 [00:15<00:00,  6.95it/s]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
# ...

# %%
m = template_bridge(num_bridge_lanes = 3)
simulate(m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 m = template_bridge(num_bridge_lanes = 3)
#       2 simulate(m)
#
# NameError: name 'template_bridge' is not defined
