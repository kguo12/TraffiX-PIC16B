# %% [raw]
# Psuedocode idea:
# 1. Load in a osmnx graph from coordinates, limit radius
# 2. Pick a random start node
# 3. Find all edges out of it and the end nodes
# 4. Append the start node to a "previously used" list
# 5. Repeat 3 and 4 for the new end nodes
# 6. Repeat whole process until certain treshold (say at most 10 nodes)

# %%
import multiprocessing as mp 
import random
import numpy as np
import osmnx as ox
import pandas as pd

np.random.seed(63)


#Gp = ox.projection.project_graph(G)

# %%
from traffix import *
import networkx as nx

# %%
G = ox.graph.graph_from_point((37.79, -122.41), dist=750, network_type="drive")

# Get the edges that form cycles
i = 0
while not nx.is_directed_acyclic_graph(G):
    i += 1
    edges_to_remove = list(nx.find_cycle(G, orientation="original"))
    G.remove_edges_from(edges_to_remove)
    if i == 1000:
        print("i")
        break
        
components = list(nx.weakly_connected_components(G))

# Select the largest weakly connected component
largest_component = max(components, key=len)

# Create a new graph with only this component
G_new = G.subgraph(largest_component).copy()

G.remove_nodes_from(list(nx.isolates(G_new)))

# Check if the new graph is weakly connected
print(nx.is_weakly_connected(G_new)) 
print(nx.is_directed_acyclic_graph(G_new))
# Out:
# True
# True

# %%
nx.draw(G_new)

# %%
nodes, edges = ox.graph_to_gdfs(G_new)

# %%
nodes
# Out:
#                     y           x          highway  street_count  \
# osmid
# 65336961    37.794065 -122.407914  traffic_signals             4
# 386885670   37.788377 -122.407772              NaN             3
# 6319217960  37.790156 -122.408854  traffic_signals             4
# 6319217961  37.791087 -122.409044  traffic_signals             4
# 6319217963  37.792044 -122.409235  traffic_signals             4
# 6319217969  37.792056 -122.409143  traffic_signals             4
# 6319217970  37.791098 -122.408952  traffic_signals             4
# 65328705    37.791505 -122.405760  traffic_signals             4
# 65295311    37.792050 -122.409184  traffic_signals             4
# 65332833    37.793858 -122.409554  traffic_signals             4
# 65307368    37.793321 -122.406662              NaN             3
# 6988532585  37.788293 -122.408434  traffic_signals             6
# 65307376    37.793185 -122.407736  traffic_signals             4
# 6378899315  37.789711 -122.407036              NaN             3
# 65352435    37.791301 -122.407358  traffic_signals             4
# 65307381    37.792979 -122.409365  traffic_signals             6
# 5020557558  37.793402 -122.409453              NaN             2
# 6378899319  37.789496 -122.406510              NaN             3
# 65303544    37.789229 -122.408616  traffic_signals             6
# 65319933    37.790570 -122.405599  traffic_signals             4
# 65336959    37.794201 -122.406841              NaN             4
#
#                                geometry
# osmid
# 65336961    POINT (-122.40791 37.79407)
# 386885670   POINT (-122.40777 37.78838)
# 6319217960  POINT (-122.40885 37.79016)
# 6319217961  POINT (-122.40904 37.79109)
# 6319217963  POINT (-122.40924 37.79204)
# 6319217969  POINT (-122.40914 37.79206)
# 6319217970   POINT (-122.40895 37.7911)
# 65328705     POINT (-122.40576 37.7915)
# 65295311    POINT (-122.40918 37.79205)
# 65332833    POINT (-122.40955 37.79386)
# 65307368    POINT (-122.40666 37.79332)
# 6988532585  POINT (-122.40843 37.78829)
# 65307376    POINT (-122.40774 37.79319)
# 6378899315  POINT (-122.40704 37.78971)
# 65352435     POINT (-122.40736 37.7913)
# 65307381    POINT (-122.40936 37.79298)
# 5020557558   POINT (-122.40945 37.7934)
# 6378899319   POINT (-122.40651 37.7895)
# 65303544    POINT (-122.40862 37.78923)
# 65319933     POINT (-122.4056 37.79057)
# 65336959     POINT (-122.40684 37.7942)

# %%
len(nodes)
# Out:
# 21

# %%
edges = edges.reset_index()
edges
# Out:
#              u           v  key  \
# 0     65336961    65336959    0
# 1   6319217960    65303544    0
# 2   6319217961  6319217960    0
# 3   6319217963  6319217961    0
# 4   6319217969    65307381    0
# 5   6319217970  6319217969    0
# 6     65328705    65352435    0
# 7     65332833    65336961    0
# 8   6988532585   386885670    1
# 9     65307376    65307381    0
# 10  6378899315    65307376    0
# 11    65352435  6319217970    0
# 12    65307381    65295311    0
# 13    65307381  5020557558    0
# 14    65307381  6319217963    0
# 15  5020557558    65332833    0
# 16  6378899319  6378899315    0
# 17    65303544  6988532585    0
# 18    65319933    65328705    0
# 19    65336959    65307368    0
#
#                                                 osmid        highway  \
# 0                                           461084154       tertiary
# 1                                           674757879       tertiary
# 2                                           674757880       tertiary
# 3                                           674757881       tertiary
# 4                              [513676827, 674757884]       tertiary
# 5                                           674757885       tertiary
# 6                                           329596844      secondary
# 7                                            91182069       tertiary
# 8                                           667569398       tertiary
# 9                                           734004334       tertiary
# 10  [8921866, 681183503, 417099350, 397146711, 397...       tertiary
# 11                                          329596844      secondary
# 12                                          100400942         busway
# 13                                          513676830       tertiary
# 14                                          674757882       tertiary
# 15                                          513676831       tertiary
# 16                                          681183504  tertiary_link
# 17                                          512523366       tertiary
# 18                           [1041351160, 1041351161]    residential
# 19                                            8920514    residential
#
#         lanes                                name  oneway       reversed  \
# 0           2                         Clay Street    True          False
# 1         NaN                       Powell Street    True          False
# 2         NaN                       Powell Street    True          False
# 3         NaN                       Powell Street    True          False
# 4           1                       Powell Street    True          False
# 5         NaN                       Powell Street    True          False
# 6           2                         Pine Street    True          False
# 7           1                         Clay Street    True          False
# 8           1                         Post Street    True          False
# 9           2                   Sacramento Street    True          False
# 10  [2, 4, 3]  [Stockton Tunnel, Stockton Street]   False  [False, True]
# 11          2                         Pine Street    True          False
# 12        NaN                                 NaN    True          False
# 13        NaN                       Powell Street   False          False
# 14          1                       Powell Street    True          False
# 15          1                       Powell Street    True          False
# 16        NaN                                 NaN    True          False
# 17        NaN                       Powell Street   False           True
# 18     [2, 1]                        Grant Avenue    True          False
# 19        NaN                       Waverly Place    True          False
#
#         length                                           geometry maxspeed  \
# 0    95.432133  LINESTRING (-122.40791 37.79407, -122.40783 37...      NaN
# 1   105.956068  LINESTRING (-122.40885 37.79016, -122.40884 37...   25 mph
# 2   104.816723  LINESTRING (-122.40904 37.79109, -122.40903 37...   25 mph
# 3   107.724096  LINESTRING (-122.40924 37.79204, -122.40923 37...   25 mph
# 4   106.869190  LINESTRING (-122.40914 37.79206, -122.40915 37...   25 mph
# 5   107.757099  LINESTRING (-122.40895 37.7911, -122.40897 37....   25 mph
# 6   142.282397  LINESTRING (-122.40576 37.7915, -122.40583 37....   25 mph
# 7   145.962639  LINESTRING (-122.40955 37.79386, -122.40952 37...      NaN
# 8    61.587465  LINESTRING (-122.40843 37.78829, -122.40841 37...      NaN
# 9   144.937156  LINESTRING (-122.40774 37.79319, -122.40784 37...      NaN
# 10  391.149954  LINESTRING (-122.40704 37.78971, -122.40709 37...      NaN
# 11  141.847112  LINESTRING (-122.40736 37.7913, -122.40746 37....   25 mph
# 12  104.678863  LINESTRING (-122.40936 37.79298, -122.40937 37...   25 mph
# 13   47.656400  LINESTRING (-122.40936 37.79298, -122.40938 37...   25 mph
# 14  106.508613  LINESTRING (-122.40936 37.79298, -122.40938 37...   25 mph
# 15   54.783666  LINESTRING (-122.40945 37.7934, -122.40945 37....      NaN
# 16   57.164048  LINESTRING (-122.40651 37.7895, -122.4068 37.7...      NaN
# 17  105.279814  LINESTRING (-122.40862 37.78923, -122.4086 37....   25 mph
# 18  105.185841  LINESTRING (-122.4056 37.79057, -122.40559 37....      NaN
# 19   99.091149  LINESTRING (-122.40684 37.7942, -122.40683 37....      NaN
#
#    tunnel access
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
# 5     NaN    NaN
# 6     NaN    NaN
# 7     NaN    NaN
# 8     NaN    NaN
# 9     NaN    NaN
# 10    yes    NaN
# 11    NaN    NaN
# 12    NaN     no
# 13    NaN    NaN
# 14    NaN    NaN
# 15    NaN    NaN
# 16    NaN    NaN
# 17    NaN    NaN
# 18    NaN    NaN
# 19    NaN    NaN

# %%
edges['length'] = max(round(edges['length'] / 50 * 50, 50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18640\3441714950.py in ?()
# ----> 1 edges['length'] = max(round(edges['length'] / 50, 0) * 50, 50)
#
# ~\anaconda3\envs\PIC16B-25W\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1469         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
edges
edges.loc[edges['length'] == 100, 'length'] = 2423
edges
edges['lanes'].fillna(1, inplace=True)
edges['lanes'] = edges['lanes'].apply(lambda x: 1 if isinstance(x, list) else x)
edges
# Out:
#              u           v  key  \
# 0     65336961    65336959    0
# 1   6319217960    65303544    0
# 2   6319217961  6319217960    0
# 3   6319217963  6319217961    0
# 4   6319217969    65307381    0
# 5   6319217970  6319217969    0
# 6     65328705    65352435    0
# 7     65332833    65336961    0
# 8   6988532585   386885670    1
# 9     65307376    65307381    0
# 10  6378899315    65307376    0
# 11    65352435  6319217970    0
# 12    65307381    65295311    0
# 13    65307381  5020557558    0
# 14    65307381  6319217963    0
# 15  5020557558    65332833    0
# 16  6378899319  6378899315    0
# 17    65303544  6988532585    0
# 18    65319933    65328705    0
# 19    65336959    65307368    0
#
#                                                 osmid        highway lanes  \
# 0                                           461084154       tertiary     2
# 1                                           674757879       tertiary     1
# 2                                           674757880       tertiary     1
# 3                                           674757881       tertiary     1
# 4                              [513676827, 674757884]       tertiary     1
# 5                                           674757885       tertiary     1
# 6                                           329596844      secondary     2
# 7                                            91182069       tertiary     1
# 8                                           667569398       tertiary     1
# 9                                           734004334       tertiary     2
# 10  [8921866, 681183503, 417099350, 397146711, 397...       tertiary     1
# 11                                          329596844      secondary     2
# 12                                          100400942         busway     1
# 13                                          513676830       tertiary     1
# 14                                          674757882       tertiary     1
# 15                                          513676831       tertiary     1
# 16                                          681183504  tertiary_link     1
# 17                                          512523366       tertiary     1
# 18                           [1041351160, 1041351161]    residential     1
# 19                                            8920514    residential     1
#
#                                   name  oneway       reversed  length  \
# 0                          Clay Street    True          False  2423.0
# 1                        Powell Street    True          False  2423.0
# 2                        Powell Street    True          False  2423.0
# 3                        Powell Street    True          False  2423.0
# 4                        Powell Street    True          False  2423.0
# 5                        Powell Street    True          False  2423.0
# 6                          Pine Street    True          False   150.0
# 7                          Clay Street    True          False   150.0
# 8                          Post Street    True          False    50.0
# 9                    Sacramento Street    True          False   150.0
# 10  [Stockton Tunnel, Stockton Street]   False  [False, True]   400.0
# 11                         Pine Street    True          False   150.0
# 12                                 NaN    True          False  2423.0
# 13                       Powell Street   False          False    50.0
# 14                       Powell Street    True          False  2423.0
# 15                       Powell Street    True          False    50.0
# 16                                 NaN    True          False    50.0
# 17                       Powell Street   False           True  2423.0
# 18                        Grant Avenue    True          False  2423.0
# 19                       Waverly Place    True          False  2423.0
#
#                                              geometry maxspeed tunnel access
# 0   LINESTRING (-122.40791 37.79407, -122.40783 37...      NaN    NaN    NaN
# 1   LINESTRING (-122.40885 37.79016, -122.40884 37...   25 mph    NaN    NaN
# 2   LINESTRING (-122.40904 37.79109, -122.40903 37...   25 mph    NaN    NaN
# 3   LINESTRING (-122.40924 37.79204, -122.40923 37...   25 mph    NaN    NaN
# 4   LINESTRING (-122.40914 37.79206, -122.40915 37...   25 mph    NaN    NaN
# 5   LINESTRING (-122.40895 37.7911, -122.40897 37....   25 mph    NaN    NaN
# 6   LINESTRING (-122.40576 37.7915, -122.40583 37....   25 mph    NaN    NaN
# 7   LINESTRING (-122.40955 37.79386, -122.40952 37...      NaN    NaN    NaN
# 8   LINESTRING (-122.40843 37.78829, -122.40841 37...      NaN    NaN    NaN
# 9   LINESTRING (-122.40774 37.79319, -122.40784 37...      NaN    NaN    NaN
# 10  LINESTRING (-122.40704 37.78971, -122.40709 37...      NaN    yes    NaN
# 11  LINESTRING (-122.40736 37.7913, -122.40746 37....   25 mph    NaN    NaN
# 12  LINESTRING (-122.40936 37.79298, -122.40937 37...   25 mph    NaN     no
# 13  LINESTRING (-122.40936 37.79298, -122.40938 37...   25 mph    NaN    NaN
# 14  LINESTRING (-122.40936 37.79298, -122.40938 37...   25 mph    NaN    NaN
# 15  LINESTRING (-122.40945 37.7934, -122.40945 37....      NaN    NaN    NaN
# 16  LINESTRING (-122.40651 37.7895, -122.4068 37.7...      NaN    NaN    NaN
# 17  LINESTRING (-122.40862 37.78923, -122.4086 37....   25 mph    NaN    NaN
# 18  LINESTRING (-122.4056 37.79057, -122.40559 37....      NaN    NaN    NaN
# 19  LINESTRING (-122.40684 37.7942, -122.40683 37....      NaN    NaN    NaN

# %%
import importlib
from traffix import *
import multiprocessing as mp 
import random
import numpy as np
import osmnx as ox
import pandas as pd
import networkx as nx


def irl_to_traffix_model(coordinates, radius):
    """
    coordinates - tuple for x and y coordinates
    radius - how large of an area you want to map
    The maximum number of nodes it will plot is 25. It will raise an Assertion error if the inputted area
    is too large, asking the user to reduce.
    """
    # Load in OSMNX graph
    G_raw = ox.graph.graph_from_point(coordinates, dist=radius, network_type="drive")
    
    # Graph reduction to acyclic graph for modeling purposes, remove isolated nodes, get weakly-connected graph
    while not nx.is_directed_acyclic_graph(G_raw):
        edges_to_remove = list(nx.find_cycle(G_raw, orientation="original"))
        G_raw.remove_edges_from(edges_to_remove)
    components = list(nx.weakly_connected_components(G_raw))
    largest_component = max(components, key=len)
    G = G_raw.subgraph(largest_component).copy()
    G.remove_nodes_from(list(nx.isolates(G)))

    # Check for weakly-connected, directed acyclic, size of graph is feasible
    assert nx.is_weakly_connected(G), "Invalid Area. Resulting map is not weakly connected/not present."
    assert nx.is_directed_acyclic_graph(G), "Invalid Area. Modifications did not produce a DAG. Please choose a different area."
    assert len(G.nodes) <= 25, "Please reduce the size of the requested region (lower radius, choose less dense area)."
    
    # Get positions based on node coordinates for more accurate visualization (using geo Pandas dataframes)
    nodes, edges = ox.graph_to_gdfs(G)
    nodes = nodes.reset_index()
    edges = edges.reset_index()
    # Normalize coords
    nodes['xpos'] = (nodes['x'] - nodes['x'].min()) / (nodes['x'].max() - nodes['x'].min())
    nodes['ypos'] = (nodes['y'] - nodes['y'].min()) / (nodes['y'].max() - nodes['y'].min())
    # Round edge lengths to nearest multiple of 50, nonzero (for seg_len purposes in traffix.py)
    edges['length'] = round(edges['length'] / 50, 0) * 50
    edges.loc[edges['length'] == 0, 'length'] = 50
    # Fill in lane NaN and invalid values (e.g. lists) with 1
    edges['lanes'].fillna(1, inplace=True)
    edges['lanes'] = edges['lanes'].apply(lambda x: 1 if isinstance(x, list) else x)
    edges['lanes'] = edges['lanes'].astype(int)
    print(edges['lanes'])
    print(type(edges['lanes']))
    
    # Instantiation of TraffiX model
    model = Map(confirmation_messages = True)
    
    for node_row in range(len(nodes)):
        name = nodes.loc[node_row, 'osmid']
        position = (nodes.loc[node_row, 'xpos'], nodes.loc[node_row, 'ypos'])
        model.add_inter(label=name, pos=position)
        
    #m.add_road(1, 2, dt=1, speed_limit=50, length=100, lanes=1, num_cars=0)
    for edge_row in range(len(edges)):
        start = edges.loc[edge_row, 'u']
        end = edges.loc[edge_row, 'v']
        speed_limit = 50
        # this is a shortcoming of the osmnx dataset. Speed limits are often not listed for road segments so we just make this assumption here.
        # really, this model makes a lot of gross assumptions, so this comparatively isn't too gross.
        length = edges.loc[edge_row, 'length']
        lanes = edges.loc[edge_row, 'lanes']
        model.add_road(start, end, dt=1, speed_limit=speed_limit, length=length, lanes=lanes, num_cars=0)
    
    print(f"""
    Uncompiled model of IRL road network at {coordinates} with radius {radius} returned.
    Please declare input nodes and initialize number of cars to sinks before compilation.
    The current summary of the graph (with sinks) and a sketch of the graph are below.
    """)
    model.get_summary()
    nx.draw(model.G, pos=model.node_positions)
    
    # Display root nodes for potential inputs the user can provide
    in_degrees = dict(self.G.in_degree(self.G.nodes))
    roots = [node for node in in_degrees if in_degrees[node] == 0]
    print(f"""
    For reference, the root nodes that can serve as potential inputs are:
    {roots}
    """
    
    return model

# %%
model = irl_to_traffix_model(coordinates=(37.79, -122.41), radius=750)
# Out:
# 0     2
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     2
# 7     1
# 8     1
# 9     2
# 10    1
# 11    2
# 12    1
# 13    1
# 14    1
# 15    1
# 16    1
# 17    1
# 18    1
# 19    1
# Name: lanes, dtype: int32
# <class 'pandas.core.series.Series'>
#
#             Road network initialized. Methods:
#
#             - .add_inter(label, pos)
#             - .add_road(start, end, dt, speed_limit, lanes, num_cars = 0)
#             - .simulation_status_check()
#
# Intersection 65336961 added.
# Intersection 386885670 added.
# Intersection 6319217960 added.
# Intersection 6319217961 added.
# Intersection 6319217963 added.
# Intersection 6319217969 added.
# Intersection 6319217970 added.
# Intersection 65328705 added.
# Intersection 65295311 added.
# Intersection 65332833 added.
# Intersection 65307368 added.
# Intersection 6988532585 added.
# Intersection 65307376 added.
# Intersection 6378899315 added.
# Intersection 65352435 added.
# Intersection 65307381 added.
# Intersection 5020557558 added.
# Intersection 6378899319 added.
# Intersection 65303544 added.
# Intersection 65319933 added.
# Intersection 65336959 added.
# Intersection (65336961,65336959) S0 added.
# Road with 2 lanes between 65336961 and 65336959 added.
# Intersection (6319217960,65303544) S0 added.
# Road with 1 lanes between 6319217960 and 65303544 added.
# Intersection (6319217961,6319217960) S0 added.
# Road with 1 lanes between 6319217961 and 6319217960 added.
# Intersection (6319217963,6319217961) S0 added.
# Road with 1 lanes between 6319217963 and 6319217961 added.
# Intersection (6319217969,65307381) S0 added.
# Road with 1 lanes between 6319217969 and 65307381 added.
# Intersection (6319217970,6319217969) S0 added.
# Road with 1 lanes between 6319217970 and 6319217969 added.
# Intersection (65328705,65352435) S0 added.
# Intersection (65328705,65352435) S1 added.
# Road with 2 lanes between 65328705 and 65352435 added.
# Intersection (65332833,65336961) S0 added.
# Intersection (65332833,65336961) S1 added.
# Road with 1 lanes between 65332833 and 65336961 added.
# Road with 1 lanes between 6988532585 and 386885670 added.
# Intersection (65307376,65307381) S0 added.
# Intersection (65307376,65307381) S1 added.
# Road with 2 lanes between 65307376 and 65307381 added.
# Intersection (6378899315,65307376) S0 added.
# Intersection (6378899315,65307376) S1 added.
# Intersection (6378899315,65307376) S2 added.
# Intersection (6378899315,65307376) S3 added.
# Intersection (6378899315,65307376) S4 added.
# Intersection (6378899315,65307376) S5 added.
# Intersection (6378899315,65307376) S6 added.
# Road with 1 lanes between 6378899315 and 65307376 added.
# Intersection (65352435,6319217970) S0 added.
# Intersection (65352435,6319217970) S1 added.
# Road with 2 lanes between 65352435 and 6319217970 added.
# Intersection (65307381,65295311) S0 added.
# Road with 1 lanes between 65307381 and 65295311 added.
# Road with 1 lanes between 65307381 and 5020557558 added.
# Intersection (65307381,6319217963) S0 added.
# Road with 1 lanes between 65307381 and 6319217963 added.
# Road with 1 lanes between 5020557558 and 65332833 added.
# Road with 1 lanes between 6378899319 and 6378899315 added.
# Intersection (65303544,6988532585) S0 added.
# Road with 1 lanes between 65303544 and 6988532585 added.
# Intersection (65319933,65328705) S0 added.
# Road with 1 lanes between 65319933 and 65328705 added.
# Intersection (65336959,65307368) S0 added.
# Road with 1 lanes between 65336959 and 65307368 added.
#
#     Uncompiled model of IRL road network at (37.79, -122.41) with radius 750 returned.
#     Please declare input nodes and initialize number of cars to sinks before compilation.
#     The current summary of the graph (with sinks) and a sketch of the graph are below.
#
#
#         Resources Used:
#         - Total length of road used: 2850.0 units
#         - Total number of lanes: 24
#         Key Nodes:
#         - Inputs: []
#         - Sinks: [386885670, 65295311, 65307368]
#         - Sink destination amounts/Total traffic: {}
