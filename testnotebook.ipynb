# %%
from uclapathfinder import optimal_walk_route

# %%
start = (34.072845, -118.453303) # Olympic Hall
end = (34.0696449790177, -118.44300984639733) # Geology Building
optimal_walk_route(start,end)
# Out:
# Start at: Latitude:  34.0730137 Longitude:  -118.452987
# End at: Latitude:  34.0696826 Longitude:  -118.443074
